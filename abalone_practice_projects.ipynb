# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cols=["Sex","Length","Diametor","Height","Whole Weight","Shucked Weight","Viscera Weight","Shell Weight","Rings"]
df=pd.read_csv("abalone_dataset_new.csv",header=None,names=cols)
df.head(10)
# Out:
#   Sex  Length  Diametor  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell Weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# 5         0.120      8
# 6         0.330     20
# 7         0.260     16
# 8         0.165      9
# 9         0.320     19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diametor        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole Weight    4177 non-null   float64
#  5   Shucked Weight  4177 non-null   float64
#  6   Viscera Weight  4177 non-null   float64
#  7   Shell Weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
cols
# Out:
# ['Sex',
#  'Length',
#  'Diametor',
#  'Height',
#  'Whole Weight',
#  'Shucked Weight',
#  'Viscera Weight',
#  'Shell Weight',
#  'Rings']

# %%
df.describe()
# Out:
#             Length     Diametor       Height  Whole Weight  Shucked Weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera Weight  Shell Weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diametor          0
# Height            0
# Whole Weight      0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# Rings             0
# dtype: int64

# %%
df.shape
# Out:
# (4177, 9)

# %%
sns.pairplot(df)

# %%
x=df.iloc[:,1:]
x
# Out:
#       Length  Diametor  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4177 rows x 8 columns]

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,11):
    kmeans =KMeans(n_clusters=i,random_state=1)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [44860.37897595209,
#  18861.998927978795,
#  9889.828962494772,
#  6340.081927459637,
#  4384.829916627339,
#  3438.38973763784,
#  2706.8677666982126,
#  2331.3658828700873,
#  2021.4831956304506,
#  1717.8814779488648]

# %%
plt.plot(range(1,11),wcss)
plt.title("The Elbow method")
plt.xlabel("Number of Clusters")
plt.ylabel("Wcss")
plt.grid(True)
plt.show()

# %%
kmeans =KMeans(n_clusters=i,random_state=1)
ykmeans=kmeans.fit_predict(x)

# %%
ykmeans
# Out:
# array([6, 0, 9, ..., 9, 1, 3])

# %%
df.drop(["Sex"], axis=1, inplace=True)

# %%
df
# Out:
#       Length  Diametor  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4177 rows x 8 columns]

# %%
df["Target"]=ykmeans
df
# Out:
#       Length  Diametor  Height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell Weight  Rings  Target
# 0           0.1500     15       6
# 1           0.0700      7       0
# 2           0.2100      9       9
# 3           0.1550     10       1
# 4           0.0550      7       0
# ...            ...    ...     ...
# 4172        0.2490     11       7
# 4173        0.2605     10       1
# 4174        0.3080      9       9
# 4175        0.2960     10       1
# 4176        0.4950     12       3
#
# [4177 rows x 9 columns]

# %%
kmeans.cluster_centers_
# Out:
# array([[4.00554700e-01, 3.04191063e-01, 1.00161787e-01, 3.46201849e-01,
#         1.58221880e-01, 7.45500770e-02, 9.78767334e-02, 6.60092450e+00],
#        [5.74629338e-01, 4.49290221e-01, 1.54093060e-01, 1.00874763e+00,
#         4.47216877e-01, 2.23127760e-01, 2.82975552e-01, 1.00000000e+01],
#        [5.99050633e-01, 4.74493671e-01, 1.72563291e-01, 1.21288608e+00,
#         4.54854430e-01, 2.48484177e-01, 3.91297468e-01, 1.81645570e+01],
#        [5.84893617e-01, 4.59851064e-01, 1.61117021e-01, 1.09104787e+00,
#         4.56306383e-01, 2.37780851e-01, 3.21014894e-01, 1.24319149e+01],
#        [4.99165202e-01, 3.85043937e-01, 1.28646749e-01, 6.42166081e-01,
#         2.94365554e-01, 1.38823374e-01, 1.79059754e-01, 7.99824253e+00],
#        [6.12777778e-01, 4.84861111e-01, 1.80138889e-01, 1.29538889e+00,
#         4.46777778e-01, 2.51402778e-01, 4.42638889e-01, 2.26388889e+01],
#        [5.80304054e-01, 4.59881757e-01, 1.64679054e-01, 1.07849324e+00,
#         4.17349662e-01, 2.33592905e-01, 3.37910473e-01, 1.48006757e+01],
#        [5.99373717e-01, 4.70595483e-01, 1.61252567e-01, 1.14255852e+00,
#         5.03977413e-01, 2.52393224e-01, 3.19865503e-01, 1.10000000e+01],
#        [2.55820106e-01, 1.87962963e-01, 6.23015873e-02, 9.66825397e-02,
#         4.59576720e-02, 2.10582011e-02, 2.85449735e-02, 4.50264550e+00],
#        [5.46865022e-01, 4.25217707e-01, 1.42721335e-01, 8.52013062e-01,
#         3.87937591e-01, 1.87802612e-01, 2.36509434e-01, 9.00000000e+00]])

# %%
x=df.iloc[:,1:]
y=df["Target"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import classification_report,confusion_matrix

# %%
def mymodel(model):
    model.fit(x_train,y_train)
    ypred = model.predict(x_test)
    print(classification_report(y_test,ypred))

# %%
logreg= LogisticRegression()
knn=KNeighborsClassifier()
svm=SVC()

# %%
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       177
#            1       1.00      1.00      1.00       139
#            2       0.97      1.00      0.99        36
#            3       1.00      1.00      1.00       144
#            4       1.00      1.00      1.00       139
#            5       1.00      0.86      0.92         7
#            6       1.00      1.00      1.00        70
#            7       1.00      1.00      1.00       121
#            8       1.00      1.00      1.00        60
#            9       1.00      1.00      1.00       152
#
#     accuracy                           1.00      1045
#    macro avg       1.00      0.99      0.99      1045
# weighted avg       1.00      1.00      1.00      1045

# %%
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       177
#            1       1.00      1.00      1.00       139
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00       144
#            4       1.00      1.00      1.00       139
#            5       1.00      1.00      1.00         7
#            6       1.00      1.00      1.00        70
#            7       1.00      1.00      1.00       121
#            8       1.00      1.00      1.00        60
#            9       1.00      1.00      1.00       152
#
#     accuracy                           1.00      1045
#    macro avg       1.00      1.00      1.00      1045
# weighted avg       1.00      1.00      1.00      1045

# %%
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       177
#            1       1.00      1.00      1.00       139
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00       144
#            4       1.00      1.00      1.00       139
#            5       1.00      1.00      1.00         7
#            6       1.00      1.00      1.00        70
#            7       1.00      1.00      1.00       121
#            8       1.00      1.00      1.00        60
#            9       1.00      1.00      1.00       152
#
#     accuracy                           1.00      1045
#    macro avg       1.00      1.00      1.00      1045
# weighted avg       1.00      1.00      1.00      1045
